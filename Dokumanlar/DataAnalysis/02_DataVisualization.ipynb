# %% [markdown]
# ## Matplotlib

# %% [markdown]
# Basit Grafik Oluşturma

# %%
import matplotlib.pyplot as plt
import numpy as np

# Veri oluşturma
aylar = ['Ocak', 'Şubat', 'Mart', 'Nisan', 'Mayıs', 'Haziran']
satis_miktarlari = [120, 150, 130, 180, 200, 220]

# Grafik oluşturma
plt.figure(figsize=(10, 6))  # Grafik boyutunu ayarlama
plt.plot(aylar, satis_miktarlari, marker='o', linestyle='-', color='b', linewidth=2)

# Grafik başlıkları ve etiketler
plt.title('Aylık Satış Miktarları', fontsize=16)
plt.xlabel('Aylar', fontsize=12)
plt.ylabel('Satış Miktarı (Adet)', fontsize=12)

# Izgara eklemek okunabilirliği artırır
plt.grid(True, linestyle='--', alpha=0.7)

# Grafik gösterimi
plt.show()

# %% [markdown]
# Kategori Karşılaştırma

# %%
import matplotlib.pyplot as plt

# Veri oluşturma
urunler = ['Ürün A', 'Ürün B', 'Ürün C', 'Ürün D']
satis_adetleri = [240, 180, 300, 210]
ortalama_fiyat = [150, 200, 120, 180]

# Grafik oluşturma
plt.figure(figsize=(12, 7))

# İlk y ekseni - Satış adetleri
ax1 = plt.subplot()
ax1.bar(urunler, satis_adetleri, color='skyblue', alpha=0.7, label='Satış Adedi')
ax1.set_xlabel('Ürünler', fontsize=12)
ax1.set_ylabel('Satış Adedi', fontsize=12, color='skyblue')
ax1.tick_params(axis='y', labelcolor='skyblue')

# İkinci y ekseni - Ortalama fiyat
ax2 = ax1.twinx()
ax2.plot(urunler, ortalama_fiyat, color='darkred', marker='s', linewidth=2, label='Ortalama Fiyat')
ax2.set_ylabel('Ortalama Fiyat (TL)', fontsize=12, color='darkred')
ax2.tick_params(axis='y', labelcolor='darkred')

# Başlık ve legend
plt.title('Ürün Bazında Satış Adedi ve Ortalama Fiyat Karşılaştırması', fontsize=14)
fig = plt.gcf()  # Mevcut figürü al
fig.legend(loc="upper right", bbox_to_anchor=(1,1), bbox_transform=ax1.transAxes)

# Grafik gösterimi
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Seaborn

# %% [markdown]
# Histogram ve Yoğunluk Grafiği

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Rastgele veri oluşturma (müşteri yaşları)
np.random.seed(42)
musteri_yaslari = np.random.normal(loc=35, scale=10, size=1000)
musteri_yaslari = np.clip(musteri_yaslari, 18, 70)  # Yaşları 18-70 aralığında sınırla

# DataFrame oluşturma
df = pd.DataFrame({'Yaş': musteri_yaslari})

# Grafik oluşturma
plt.figure(figsize=(12, 7))

# Histogram ve yoğunluk grafiği
sns.histplot(data=df, x='Yaş', bins=30, kde=True, color='teal', alpha=0.7)

# Grafik özelliklerini ayarlama
plt.title('Müşteri Yaş Dağılımı', fontsize=16)
plt.xlabel('Yaş', fontsize=12)
plt.ylabel('Frekans', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Ortalama ve medyan çizgileri ekleme
ortalama = df['Yaş'].mean()
medyan = df['Yaş'].median()
plt.axvline(ortalama, color='red', linestyle='dashed', linewidth=2, label=f'Ortalama: {ortalama:.1f}')
plt.axvline(medyan, color='green', linestyle='dashed', linewidth=2, label=f'Medyan: {medyan:.1f}')

plt.legend()
plt.show()

# %% [markdown]
# Kutu Grafiği (Box Plot) ve Violin Grafiği

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Farklı departmanlarda çalışanların maaş verisi
np.random.seed(42)
departmanlar = ['Yazılım', 'Pazarlama', 'Satış', 'İnsan Kaynakları', 'Muhasebe']
maaslar = []

for dept in departmanlar:
    if dept == 'Yazılım':
        maaslar.extend(np.random.normal(loc=15000, scale=3000, size=50))
    elif dept == 'Pazarlama':
        maaslar.extend(np.random.normal(loc=10000, scale=2000, size=50))
    elif dept == 'Satış':
        maaslar.extend(np.random.normal(loc=12000, scale=2500, size=50))
    elif dept == 'İnsan Kaynakları':
        maaslar.extend(np.random.normal(loc=9000, scale=1500, size=50))
    else:  # Muhasebe
        maaslar.extend(np.random.normal(loc=11000, scale=2000, size=50))

df = pd.DataFrame({
    'Departman': np.repeat(departmanlar, 50),
    'Maaş': maaslar
})

# Grafik oluşturma
plt.figure(figsize=(14, 8))

# Kutu grafiği
plt.subplot(1, 2, 1)
sns.boxplot(data=df, x='Departman', y='Maaş', palette='Set2')
plt.title('Departmanlara Göre Maaş Dağılımı (Kutu Grafiği)', fontsize=14)
plt.xticks(rotation=15)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Violin grafiği
plt.subplot(1, 2, 2)
sns.violinplot(data=df, x='Departman', y='Maaş', palette='Set2', inner='quartile')
plt.title('Departmanlara Göre Maaş Dağılımı (Violin Grafiği)', fontsize=14)
plt.xticks(rotation=15)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_37724/1151843292.py:33: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Departman', y='Maaş', palette='Set2')
# /tmp/ipykernel_37724/1151843292.py:40: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Departman', y='Maaş', palette='Set2', inner='quartile')

# %% [markdown]
# Korelasyon Isı Haritası

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# E-ticaret veri seti oluşturma
np.random.seed(42)
musteri_sayisi = 500

veri = {
    'Günlük_Ziyaret_Sayisi': np.random.poisson(lam=5, size=musteri_sayisi),
    'Ortalama_Sayfa_Suresi': np.random.gamma(shape=2, scale=30, size=musteri_sayisi),
    'Sepete_Eklenen_Urun_Sayisi': np.random.poisson(lam=2, size=musteri_sayisi),
    'Satın_Alma_Sayisi': np.random.poisson(lam=0.5, size=musteri_sayisi),
    'Harcama_Miktari': []
}

# Harcama miktarını satın alma sayısına bağlı olarak hesapla
for i in range(musteri_sayisi):
    if veri['Satın_Alma_Sayisi'][i] > 0:
        veri['Harcama_Miktari'].append(np.random.normal(loc=250, scale=50) * veri['Satın_Alma_Sayisi'][i])
    else:
        veri['Harcama_Miktari'].append(0)

df = pd.DataFrame(veri)

# Korelasyon matrisini hesapla
korelasyon_matrisi = df.corr()

# Grafik oluşturma
plt.figure(figsize=(12, 10))

# Isı haritası
sns.heatmap(korelasyon_matrisi,
            annot=True,
            fmt=".2f",
            cmap='coolwarm',
            linewidths=0.5,
            annot_kws={"size": 12})

plt.title('E-Ticaret Metrikleri Arasındaki Korelasyon', fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Plotly

# %% [markdown]
#  Etkileşimli Çizgi Grafiği

# %%
# %pip install plotly
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 47.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [plotly]2m1/2 [plotly]
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px
import pandas as pd
import numpy as np

# Zaman serisi verisi oluşturma
tarihler = pd.date_range(start='2023-01-01', end='2023-12-31', freq='D')
np.random.seed(42)
satislar = np.cumsum(np.random.normal(loc=10, scale=5, size=len(tarihler))) + 100

# DataFrame oluşturma
df = pd.DataFrame({
    'Tarih': tarihler,
    'Günlük Satış': satislar
})

# Etkileşimli çizgi grafiği
fig = px.line(df,
              x='Tarih',
              y='Günlük Satış',
              title='2023 Yılı Günlük Satış Performansı',
              labels={'Günlük Satış': 'Satış Miktarı', 'Tarih': 'Tarih'},
              template='plotly_white')

# Grafik özelliklerini özelleştirme
fig.update_traces(line=dict(width=2.5, color='#1f77b4'))
fig.update_layout(
    hovermode='x unified',
    xaxis_title='Tarih',
    yaxis_title='Satış Miktarı',
    font=dict(family="Arial", size=12),
    title_font_size=18,
    hoverlabel=dict(bgcolor="white", font_size=14)
)

# Trend çizgisi ekleme
fig.add_scatter(
    x=df['Tarih'],
    y=df['Günlük Satış'].rolling(window=30).mean(),
    mode='lines',
    name='30 Günlük Ortalama',
    line=dict(color='red', width=2, dash='dash')
)

fig.show()

# %% [markdown]
# Etkileşimli Dağılım Grafiği (Scatter Plot)

# %%
import plotly.express as px
import pandas as pd
import numpy as np

# Yapay veri oluşturma - E-ticaret kullanıcıları
np.random.seed(42)
kullanici_sayisi = 300

veri = {
    'Ziyaret_Sayisi': np.random.poisson(lam=8, size=kullanici_sayisi),
    'Ortalama_Sure': np.random.gamma(shape=3, scale=25, size=kullanici_sayisi),
    'Sepet_Ekleme': np.random.poisson(lam=3, size=kullanici_sayisi),
    'Satın_Alma': np.random.binomial(n=1, p=0.3, size=kullanici_sayisi),
    'Cinsiyet': np.random.choice(['Erkek', 'Kadın'], size=kullanici_sayisi, p=[0.48, 0.52])
}

df = pd.DataFrame(veri)

# Satın alma olasılığını hesapla
df['Satın_Alma_Olasiligi'] = df['Satın_Alma'].map({0: 'Satın Alma Yok', 1: 'Satın Alma Var'})

# Etkileşimli dağılım grafiği
fig = px.scatter(df,
                 x='Ziyaret_Sayisi',
                 y='Ortalama_Sure',
                 size='Sepet_Ekleme',
                 color='Satın_Alma_Olasiligi',
                 hover_name='Cinsiyet',
                 title='Kullanıcı Davranış Analizi',
                 labels={
                     'Ziyaret_Sayisi': 'Aylık Ziyaret Sayısı',
                     'Ortalama_Sure': 'Ortalama Sayfa Süresi (saniye)',
                     'Sepet_Ekleme': 'Sepete Eklenen Ürün Sayısı'
                 },
                 template='plotly_white')

# Grafik düzenini iyileştirme
fig.update_traces(marker=dict(line=dict(width=1, color='DarkSlateGrey')),
                  selector=dict(mode='markers'))
fig.update_layout(
    legend_title_text='Satın Alma Durumu',
    font=dict(family="Arial", size=12),
    title_font_size=18
)

fig.show()

# %% [markdown]
# Türkiye Haritası Üzerinde Satış Dağılımı

# %%
import plotly.express as px
import pandas as pd
import numpy as np

# Türkiye illerine göre yapay satış verisi
iller = ['İstanbul', 'Ankara', 'İzmir', 'Bursa', 'Antalya', 'Adana', 'Konya', 'Gaziantep',
         'Mersin', 'Samsun', 'Diyarbakır', 'Kayseri', 'Eskişehir', 'Trabzon', 'Malatya']
np.random.seed(42)
satis_miktarlari = np.random.randint(50, 500, size=len(iller))

# DataFrame oluşturma
df = pd.DataFrame({
    'İl': iller,
    'Satış_Miktarı': satis_miktarlari
})

# Türkiye harita verisi (basitleştirilmiş koordinatlar)
turkiye_harita = {
    'İl': ['İstanbul', 'Ankara', 'İzmir', 'Bursa', 'Antalya', 'Adana', 'Konya', 'Gaziantep',
           'Mersin', 'Samsun', 'Diyarbakır', 'Kayseri', 'Eskişehir', 'Trabzon', 'Malatya'],
    'Enlem': [41.0082, 39.9334, 38.4192, 40.1825, 36.8969, 36.9916, 37.8700, 37.0662,
              36.8121, 41.2992, 37.9132, 38.7326, 39.7667, 41.0027, 38.3580],
    'Boylam': [28.9784, 32.8597, 27.1287, 29.0669, 30.7133, 35.3250, 32.4824, 37.3833,
               34.6415, 36.3356, 40.2170, 35.4852, 30.5256, 39.7163, 38.0360]
}

harita_df = pd.DataFrame(turkiye_harita)
df = pd.merge(df, harita_df, on='İl')

# Etkileşimli harita
fig = px.scatter_mapbox(df,
                        lat='Enlem',
                        lon='Boylam',
                        size='Satış_Miktarı',
                        color='Satış_Miktarı',
                        hover_name='İl',
                        hover_data=['Satış_Miktarı'],
                        color_continuous_scale=px.colors.sequential.Viridis,
                        size_max=50,
                        zoom=5,
                        title='Türkiye İllerine Göre Satış Dağılımı',
                        mapbox_style='carto-positron')

fig.update_layout(
    margin={"r":0,"t":30,"l":0,"b":0},
    coloraxis_colorbar=dict(title="Satış Miktarı")
)

fig.show()
# Out:
# /tmp/ipykernel_37724/4254624093.py:31: DeprecationWarning:
#
# *scatter_mapbox* is deprecated! Use *scatter_map* instead. Learn more at: https://plotly.com/python/mapbox-to-maplibre/
