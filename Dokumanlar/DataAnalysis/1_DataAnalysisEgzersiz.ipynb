# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.3.1'

# %%
l1 = ["a","b","c"]
l2 = [30,40,60]
s1 = pd.Series(l1,index=[2,3,4])
s1
# Out:
# 2    a
# 3    b
# 4    c
# dtype: object

# %%
df = pd.DataFrame({"sutun1":s1,"sutun2":l2})

# %%
data = {
    'Ürün': ['Laptop', 'Akıllı Telefon', 'Tablet', 'Kulaklık', 'Klavye'],
    'Fiyat': [15000, 8500, 6000, 750, 450],
    'Stok': [25, 45, 30, 120, 80],
    'Kategori': ['Bilgisayar', 'Telefon', 'Tablet', 'Aksesuar', 'Aksesuar']
}

# DataFrame oluşturma
urun_df = pd.DataFrame(data)

# %%
df = pd.read_csv("datasets/Breast_cancer_dataset.csv",)

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
df.shape
# Out:
# (569, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             568 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    568.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.286690       91.969033   654.889104
# std    1.250206e+08     3.524049      4.304247       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.835000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.802500      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %% [markdown]
# ## Erişim

# %%
df.iloc[0:5]
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.loc[:5]
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# ...

# %%
df.diagnosis
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
df["texture_mean"]
# Out:
# 0      10.38
# 1      17.77
# 2      21.25
# 3      20.38
# 4      14.34
#        ...
# 564    22.39
# 565    28.25
# 566    28.08
# 567    29.33
# 568    24.54
# Name: texture_mean, Length: 569, dtype: float64

# %%
df.iloc[0:5,1:4]
# Out:
#   diagnosis  radius_mean  texture_mean
# 0         M        17.99         10.38
# 1         M        20.57         17.77
# 2         M        19.69         21.25
# 3         M        11.42         20.38
# 4         M        20.29         14.34

# %%
df.loc[0:5,"diagnosis":"perimeter_mean"]
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean
# 0         M        17.99         10.38          122.80
# 1         M        20.57         17.77          132.90
# 2         M        19.69         21.25          130.00
# 3         M        11.42         20.38           77.58
# 4         M        20.29         14.34          135.10
# 5         M        12.45         15.70           82.57

# %%
df.loc[0:5,["diagnosis","perimeter_mean","compactness_mean"]]
# Out:
#   diagnosis  perimeter_mean  compactness_mean
# 0         M          122.80           0.27760
# 1         M          132.90           0.07864
# 2         M          130.00           0.15990
# 3         M           77.58           0.28390
# 4         M          135.10           0.13280
# 5         M           82.57           0.17000

# %%
dfFilter = df[df["perimeter_mean"]>180]

# %%
dfFilter
# Out:
#             id diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 180     873592         M        27.22         21.87           182.1
# 212    8810703         M        28.11         18.47           188.5
# 461  911296202         M        27.42         26.27           186.9
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 180     2250.0           0.1094            0.1914          0.2871
# 212     2499.0           0.1142            0.1516          0.3201
# 461     2501.0           0.1084            0.1988          0.3635
#
#      concave points_mean  ...  texture_worst  perimeter_worst  area_worst  \
# 180               0.1878  ...          32.85            220.8      3216.0
# 212               0.1595  ...          18.47            188.5      2499.0
# 461               0.1689  ...          31.37            251.2      4254.0
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 180            0.1472             0.4034           0.5340
# ...

# %%
dfFilter.reset_index(drop=True,inplace=True)

# %%
dfFilter
# Out:
#           id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0     873592         M        27.22         21.87           182.1     2250.0
# 1    8810703         M        28.11         18.47           188.5     2499.0
# 2  911296202         M        27.42         26.27           186.9     2501.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0           0.1094            0.1914          0.2871               0.1878
# 1           0.1142            0.1516          0.3201               0.1595
# 2           0.1084            0.1988          0.3635               0.1689
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          32.85            220.8      3216.0            0.1472
# 1  ...          18.47            188.5      2499.0            0.1142
# 2  ...          31.37            251.2      4254.0            0.1357
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# ...
